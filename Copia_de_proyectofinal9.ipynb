# %% [markdown]
# <a href="https://colab.research.google.com/github/lefe08/Python/blob/main/Copia_de_proyectofinal9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
@autor: leticia (y .........) 
"""
robo=['''
__________|
|         |
|
|
|
|
|==========''',
'''
_________|
|        |
|        ☻
|
|
|
|
|
|=========''',
'''
__________|
|         |
|         ☻
|        ▒▒▒
|
|
|
|
|=========''',
'''
_________|
|        |
|        ☻
|      █▒▒▒
|
|
|
|
|=========''',
'''
_________|
|        |
|        ☻
|      █▒▒▒█
|
|
|
|
|===========''',
'''
______________|
|             |
|             ☻
|           █▒▒▒█
|            █
|
|            
|
|
|==========''',
'''
__________|
|         |
|         ☻
|       █▒▒▒█
|        █ █
|
|
|
|
|============''']        
arduño={1:robo[0],2:robo[1],3:robo[2],4:robo[3],5:robo[4],6:robo[5],7:robo[6]}
palabra_secreta= 'titulo'
letras_ingresadas=[]
letras=[]
vidas=7 
robot=1

print(f'''{'=' * 34}
BIENVENIDO AL JUEGO DEL AHORCADO.
{'=' * 34} ''')

print('adivina la palabra secreta')
medida=len(palabra_secreta)
print(f'{"__ " * len(palabra_secreta)}')
while  medida>0 and vidas >0:
   print(f'te quedan {vidas} vidas y haz ingresado{letras_ingresadas}')
   letra_usuario=input('ingresa una letra')

   if letra_usuario in letras_ingresadas:
     print ('Esa letra ya la usaste') 
   else:
    letras_ingresadas.append(letra_usuario)
    if letra_usuario in palabra_secreta:
      print(letras_ingresadas)
      print(f' la letra {letra_usuario} si está en la palabra secreta')
      medida=medida - palabra_secreta.count(letra_usuario)
    else:
      print(f' La letra {letra_usuario} no está en la palabra secreta')
      vidas=vidas-1
      if robot<=7: 
       print(arduño[robot])
       robot=robot+1


if  vidas==0:
   print(f'perdiste!!!!!!!  la palabra secreta era { palabra_secreta}' )
else:
 print(f'felicidades!!!!!! atinaste en  {vidas} la palabra secreta es {palabra_secreta}')
# Out:
# ...
# BIENVENIDO AL JUEGO DEL AHORCADO.
# ...
# adivina la palabra secreta
# __ __ __ __ __ __
# te quedan 7 vidas y haz ingresado[]
# ingresa una letrat
# ['t']
#  la letra t si está en la palabra secreta
# te quedan 7 vidas y haz ingresado['t']
# ingresa una letrai
# ['t', 'i']
#  la letra i si está en la palabra secreta
# te quedan 7 vidas y haz ingresado['t', 'i']
# ingresa una letrat
# Esa letra ya la usaste
# te quedan 7 vidas y haz ingresado['t', 'i']
# ingresa una letrau
# ['t', 'i', 'u']
#  la letra u si está en la palabra secreta
# te quedan 7 vidas y haz ingresado['t', 'i', 'u']
# ingresa una letral
# ['t', 'i', 'u', 'l']
#  la letra l si está en la palabra secreta
# te quedan 7 vidas y haz ingresado['t', 'i', 'u', 'l']
# ingresa una letrao
# ['t', 'i', 'u', 'l', 'o']
#  la letra o si está en la palabra secreta
# felicidades!!!!!! atinaste en  7 la palabra secreta es titulo

# %%
#gllglhlhlh
#gllhlh


robot=['''
__________|
|         |
|
|
|
|
|==========''',
'''
_________|
|        |
|        ☻
|
|
|
|
|
|=========''',
'''
__________|
|         |
|         ☻
|        ▒▒▒
|
|
|
|
|=========''',
'''
_________|
|        |
|        ☻
|      █▒▒▒
|
|
|
|
|========='''.
'''
____________|
|           |
|           ☻
|         █▒▒▒█
|
|
|
|
|==========='''.
'''
______________|
|             |
|             ☻
|           █▒▒▒█
|            █
|
|            
|
|
|==========''',
'''
__________|
|         |
|         ☻
|       █▒▒▒█
|        █ █
|
|
|
|
|============''']
